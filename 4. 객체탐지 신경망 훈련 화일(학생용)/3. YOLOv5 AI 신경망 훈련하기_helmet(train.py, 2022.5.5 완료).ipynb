# %% [markdown]
# # Custom Training with YOLOv5
#
# In this tutorial, we assemble a dataset and train a custom YOLOv5 model to recognize the objects in our dataset. To do so we will take the following steps:
#
# * Gather a dataset of images and label our dataset
# * Export our dataset to YOLOv5
# * Train YOLOv5 to recognize the objects in our dataset
# * Evaluate our YOLOv5 model's performance
# * Run test inference to view our model at work
#
#
#
# ![](https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png)

# %% [markdown]
# # AI 신경망 훈련하기(TRAIN)

# %% [markdown]
# ## 1. yolov5 설치하기

# %% [markdown]
# %cd : 디렉토리 변경
#
# ---

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

from yolov5 import utils
display = utils.notebook_init()  # checks

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %% [markdown]
# ## 2. 미리 만들어 놓은 학습할 dataset을 colab 왼쪽에 업로드 하기

# %% [markdown]
# ## 3. dataset 압축화일 풀기

# %% [markdown]
# ** unzip : 압축풀기

# %%
# !unzip -q ../helmet30_dataset.zip -d ../

# %% [markdown]
# ** helmet_dataset에서 images의 train에 들어있는 이미지(사진)의 이름의 열거해 보자. train 내에 어떤 사진이 들어있는지 이름 목록을 출력

# %%
# !ls ../helmet_dataset/images/train

# %% [markdown]
# ### yolov5를 제외한 외부에서 다운로드한 화일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. 미리 만들어진 helmet.yaml 을 data 아래에 다운로드 한다.

# %% [markdown]
# ## 5. 주어진 data 학습하기

# %% [markdown]
# ### weights : train(학습)에 사용할 모델 지정
# ### data : dataset의 경로정보를 가진 ~.yaml 지정
# ### img : image size
# ### batch : 전체 데이터를 얼만큼 쪼개서 학습할지를 지정, 그래픽카드의 성능에 좌우 됨, 한번에 훈련할 수 있는 데이터의 수
# ### cache : cache memory 사용, 속도를 빠르게 한다.
# ### epoch : 반복 회수

# %%
# Train YOLOv5s on COCO128 for 10 epochs
# %%time
# !python train.py --img 640 --batch 2 --epochs 10 --data helmet.yaml --weights yolov5s.pt --cache

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6. yolov5 학습 튜토리얼(용어 설명)

# %% [markdown]
# # https://lynnshin.tistory.com/48
