# %% [markdown]
# # dataset 구하기

# %% [markdown]
# # 1. roboflow에서 dataset을 구해보자.

# %% [markdown]
# https://public.roboflow.com/

# %% [markdown]
# # 2. kaggle에서 dataset을 구해보자.

# %% [markdown]
# https://www.kaggle.com/datasets
