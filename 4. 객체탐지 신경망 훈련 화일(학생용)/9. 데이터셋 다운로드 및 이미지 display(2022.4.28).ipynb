# %% [markdown]
# # yolov5 모델 다운로드

# %% [markdown]
# **https://github.com/ultralytics/yolov5**
#
# **https://www.ultralytics.com**

# %%
#clone YOLOv5 and torch
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

# %% [markdown]
# # roboflow에서 pothole 이미지셋 다운로드

# %% [markdown]
# https://public.roboflow.com/

# %% [markdown]
# %mkdir : 디렉토리를 생성

# %%
# %mkdir /content/pothole
# %cd /content/pothole
# !curl -L "https://public.roboflow.com/ds/m0E5Tx4om4?key=kEKT9jhfJu" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %% [markdown]
# yolov5의 data/images에 들어있는 이미지 화일명 출력

# %%
# %cd /content/yolov5
# !ls data/images
# Out:
# /content/yolov5
# bus.jpg  zidane.jpg

# %% [markdown]
# 위 화일을 사진으로 출력해보자.

# %%
display.Image(filename = 'data/images/bus.jpg', width=600)

# %%
display.Image(filename = 'data/images/zidane.jpg', width=600)

# %% [markdown]
# pothole 내의 사진 하나를 화면에 출력해보자.

# %%
# %cd /content/pothole 
display.Image(filename = '/content/pothole/train/images/img-100_jpg.rf.233751cac3399aa80b5e58a2afbb753a.jpg', width=600)
